# %% [markdown]
# <a href="https://colab.research.google.com/github/Khushal21csu188/RLLAB-SEM-5/blob/main/RL_EXP_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,3,4,5])
y=np.array([1,2,3,4,5])
print(np.corrcoef(x,y))
plt.scatter(x,y)
# Out:
# [[1. 1.]
#  [1. 1.]]

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,3,4,5])
y=np.array([0,0,0,0,0])
print(np.corrcoef(x,y))
plt.scatter(x,y)
# Out:
# [[ 1. nan]
#  [nan nan]]
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,3,4,5])
y=np.array([-1,-2,-3,-4,-5])
print(np.corrcoef(x,y))
plt.scatter(x,y)
# Out:
# [[ 1. -1.]
#  [-1.  1.]]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data={"states":["Ohio","Ohio","Ohio","Nevada","Nevada","Nevada"],
     "year":[2000,2001,2002,2001,2002,2003],
     "pop":[1.5,1.7,3.6,2.4,2.9,3.2],
     "sex":["M","M","F","F","F","M"],
     "income":[2000,8000,1000,9000,6000,2000],
     "age":[35,98,65,51,34,11]}
df=pd.DataFrame(data)
print(df)
corr = df.corr()
corr

# %%
plt.figure(figsize=(5,2), dpi =200)
sns.heatmap(corr,annot=True,fmt=".2f", linewidth=.5)
plt.show()

# %%
pd.plotting.scatter_matrix(df, figsize=(10, 10))
plt.show()
